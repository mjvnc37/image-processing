# %%
import pandas as pd
import numpy as np
from skimage.io import imread, imshow

# loading the image
image1=imread("C:/Users/User/Downloads/rose.jpg")
imshow(image1)

# %%
#converting the original image to gray
image2= imread("C:/Users/User/Downloads/rose.jpg",as_gray=True)
imshow(image2);

# %%
#shape of image
print(image1.shape)
print(image2.shape)
# Out:
# (122, 81, 3)
# (122, 81)

# %%
#size of the image
print(image1.size)
print(image2.size)
# Out:
# 29646
# 9882

# %%
#pixel Features
pixel_features1=np.reshape(image2,(122*81))
pixel_features1.shape,pixel_features1
# Out:
# ((9882,),
#  array([0.        , 0.        , 0.        , ..., 0.04371765, 0.04371765,
#         0.04124039]))

# %%
#pixel Features
pixel_features2=np.reshape(image1,(122*81*3))
pixel_features2.shape,pixel_features2
# Out:
# ((29646,), array([ 0,  0,  0, ...,  4, 12, 15], dtype=uint8))

# %%
from PIL import Image,ImageStat
im=Image.open("C:/Users/User/Downloads/rose.jpg")
stat=ImageStat.Stat(im)
print(stat.var)
# Out:
# [4223.557712980382, 2763.837958421415, 1396.8845234012306]

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read an image
image = cv2.imread("C:/Users/User/Downloads/rose.jpg")

# Apply log transformation method
c = 255 / np.log(1 + np.max(image))
log_image = c * (np.log(image + 1))

# Specify the data type so that
# float value will be converted to int
log_image = np.array(log_image, dtype = np.uint8)

# Display both images
plt.imshow(image)
plt.show()
plt.imshow(log_image)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_7788/1471571697.py:10: RuntimeWarning: divide by zero encountered in log
#   log_image = c * (np.log(image + 1))
